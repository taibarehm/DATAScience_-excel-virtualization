# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats
from warnings import filterwarnings
filterwarnings('ignore')
pd.set_option('display.max_column',None)

# %%
excel_red=pd.read_csv("C:/Users/ASU/Desktop/IITD/DATAScience/insurance.csv")
excel_red
# Out:
#         id  age     sex     bmi  children smoker     region      charges
# 0     1001   19  female  27.900         0    yes  southwest  16884.92400
# 1     1002   18    male  33.770         1     no  southeast   1725.55230
# 2     1003   28    male  33.000         3     no  southeast   4449.46200
# 3     1004   33    male  22.705         0     no  northwest  21984.47061
# 4     1005   32    male  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 1333  2334   50    male  30.970         3     no  northwest  10600.54830
# 1334  2335   18  female  31.920         0     no  northeast   2205.98080
# 1335  2336   18  female  36.850         0     no  southeast   1629.83350
# 1336  2337   21  female  25.800         0     no  southwest   2007.94500
# 1337  2338   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 8 columns]

# %%
sns.histplot(x='age',data=excel_red)
plt.title("Range of Age's",fontsize=20)
"""Histograms represent a variable in the form of bars,where the surface of each bar is proportional to the frequency of the values represented. They offer an overview of the distribution of a population or sample with respect to a given characteristic.In this sample the max population are of 20 age where min number of population are of 40 Age"""
# Out:
# 'Histograms represent a variable in the form of bars,where the surface of each bar is proportional to the frequency of the values represented. They offer an overview of the distribution of a population or sample with respect to a given characteristic.In this sample the max population are of 20 age where min number of population are of 40 Age'

# %%
sns.set(style ="ticks")
sns.histplot(
    x='sex',data=excel_red)

plt.title('sex', fontsize = 20)
"""A Histograms chart describes the comparisons between the Sex and the total number of count of a sample."""
# Out:
# 'A Histograms chart describes the comparisons between the Sex and the total number of count of a sample.'

# %%
sns.set(style ="ticks")
sns.histplot(
    x='smoker',data=excel_red)
plt.title("Range of smoker's",fontsize=20)
"""A Histograms chart describes the comparisons between the smoker and the total number of count of a sample."""
# Out:
# 'A Histograms chart describes the comparisons between the smoker and the total number of count of a sample.'

# %%
sns.boxplot(x= 'bmi', data=excel_red, color = 'r')
plt.title("Range of BMI's",fontsize=20)

"""Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into three quartiles
 This graph represents the minimum btween 25 to 30 , maximum btween 30 to 35 , median to be 35 """
# Out:
# 'Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into three quartiles\n This graph represents the minimum btween 25 to 30 , maximum btween 30 to 35 , median to be 35 '

# %%
##Box plot: horizontal
sns.boxplot(x= 'charges', data=excel_red, color = 'r')
plt.title("Range of charges's",fontsize=20)
""" This graph represents the minimum, maximum, median, """
# Out:
# ' This graph represents the minimum, maximum, median, '

# %%
sns.set(style ="ticks")
sns.histplot(
    x='region',data=excel_red)
plt.title("Range of region's",fontsize=20)
# Out:
# Text(0.5, 1.0, "Range of region's")

# %%
sns.boxplot(x= 'children', data=excel_red, color = 'b')
plt.ylabel('no of children', fontsize = 15)

"""A Histograms chart describes the comparisons between the region and the total number of count of a sample.Where the max population are of from southwest"""
# Out:
# 'A Histograms chart describes the comparisons between the region and the total number of count of a sample.Where the max population are of from southwest'

# %%
sns.jointplot(x='age', y= 'bmi', kind = 'reg', data = excel_red, color = 'g')
plt.title('Age with respect to BMI', fontsize = 15)
"""here in the graph, visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.
Distribution of Age with respect to BMI  """
# Out:
# 'here in the graph, visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.\nDistribution of Age with respect to BMI  '

# %%
l=[]
for i in excel_red.children:
    if i not in  l:
        l.append(i)
print(l)
"""list of nuber of chlidren sample have min 0 and Max 4"""
# Out:
# [0, 1, 3, 2, 5, 4]
# 'list of nuber of chlidren sample have min 0 and Max 4'

# %%
#list of nuber of chlidren sample have min 0 and Max 4
# a=[0, 1, 3, 2, 5, 4]


colors = {0:'orange', 1:'blue',3:'green',2:'grey',5:'yellow',4:'red'}
color_ls = [colors[i] for i in excel_red.children]
s=excel_red.age
z=excel_red.bmi
# plot
plt.scatter(s, z, c=color_ls)
plt.xlabel("Age of sample")
plt.ylabel("BMI of Sample")
plt.title("BMI v/s Weight with respect to number of children they have")
plt.show()
"""BMI v/s Weight with respect to number of children they have of difrent color dots"""
# Out:
# 'BMI v/s Weight with respect to number of children they have of difrent color dots'

# %%
sns.set(style ="ticks")
sns.histplot(
    x='charges',data=excel_red,color='yellow')
plt.title("Range of charges's",fontsize=20)
"""Graph for charges in the form bar graph ,here . A bar chart describes the comparisons between the Charges and the total number of count od a sample."""
# Out:
# 'Graph for charges in the form bar graph ,here . A bar chart describes the comparisons between the Charges and the total number of count od a sample.'

# %%
"""Adding a Hue Color"""
Cda = excel_red[['age', 'bmi', 'charges','children']]
sns.pairplot(Cda, hue='age')

# %%
"""How to Modify Colors in a Seaborn Pairplot
Age vs BMI vs charges with respect to no of children"""
sns.pairplot(Cda, hue='children',palette='hls')

# %%
"""Do an analysis of ‘sex’ and ‘smoker’ and comment on whether females smoke more 
than men or men smoke more than females, in max 30 words
with logical method
"""
list3=zip(excel_red.sex,excel_red.smoker)
print(list3)
femaelwhoSmoke=0
femaelwhoDontsmoke=0
maelwhoSmoke=0
maelwhoDontsmoke=0
for i ,j in list3:
    if i=='female'and j=='yes':
        femaelwhoSmoke+=1
    #else:
    elif i=='female'and j=='no':
            femaelwhoDontsmoke+=1
    elif i=='male'and j=='yes':
            maelwhoSmoke+=1
    elif i=='male'and j=='no':
            maelwhoDontsmoke+=1
   
        
        
print(maelwhoDontsmoke,"Male Who Don't Smoke")
print(maelwhoSmoke,"Male Who Smoke")
print(femaelwhoSmoke,"Femal Who Smoke")
print(femaelwhoDontsmoke,"Female Who Dont Smoke")
# Out:
# ...
# 517 Male Who Don't Smoke
# 159 Male Who Smoke
# 115 Femal Who Smoke
# 547 Female Who Dont Smoke

# %%
"""Do an analysis of ‘sex’ and ‘smoker’ and comment on whether females smoke more 
than men or men smoke more than females, in max 30 words
with direct method 
here variable femaelwhoSmoke femael who smoke 
variable maelwhoSmoke mael who smoke 
variable femaelwhoDontsmoke femael who dont smoke 
variable maelwhoDontsmoke mael who dont smoke 
"""

femaelwhoSmoke=excel_red[(excel_red.sex=='female') & (excel_red.smoker=="yes")].count()
maelwhoSmoke=excel_red[(excel_red.sex=='male') & (excel_red.smoker=="yes")].count()
femaelwhoDontsmoke=excel_red[(excel_red.sex=='female') & (excel_red.smoker=="no")].count()
maelwhoDontsmoke=excel_red[(excel_red.sex=='male') & (excel_red.smoker=="no")].count()

if femaelwhoSmoke.id>maelwhoSmoke.id:
    
    print("Female Smoke more than Male")
else:
    print("Male Smoke more than Female")
# Out:
# Male Smoke more than Female

# %%
lisst={"femaelYes":femaelwhoSmoke.id,"maelYes":maelwhoSmoke.id,"femaelNo":femaelwhoDontsmoke.id,"maelNo":maelwhoDontsmoke.id}
lisst
# Out:
# {'femaelYes': 115, 'maelYes': 159, 'femaelNo': 547, 'maelNo': 517}

# %%
"""autopct attribute is used to specify the distance of the text in the slice from the center of the circle."""
  
# define Seaborn color palette to use
palette_color = sns.color_palette('bright')
  
# plotting data on chart
plt.pie(lisst.values(), labels=lisst.keys(), colors=palette_color, autopct='%.0f%%')
  
# displaying chart
plt.show()

# %%
"""Analyze and figure out ‘charges’ are more connected to ‘age’, ‘bmi’ or ‘children’. 
Give rationale of your conclusion in max 30 words
Analyzed  as below
"""
"""Adding a Hue Color"""
Cda = excel_red[['age', 'bmi', 'charges','children']]
sns.pairplot(Cda,palette='hls',hue='charges')

# %%
sns.heatmap(Cda.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
# !pip install pandas plotnine

# %%
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap

# %%
(ggplot(excel_red, aes('age', 'bmi','children','charges', color='factor(smoker)'))
+ geom_point()
+ stat_smooth(method='lm')
+ facet_wrap('~smoker')
)
# Out:
# <ggplot: (159456900256)>

# %%
#b  BMI VS Charges with respect to children 
(ggplot(excel_red, aes( 'bmi','charges', color='factor(children)'))
+ geom_point()
+ stat_smooth(method='lm')
+ facet_wrap('~children')
)
# Out:
# <ggplot: (159457558140)>

# %%
#age', 'bmi','children','charges
(ggplot(excel_red, aes( 'age','charges', color='factor(children)'))
+ geom_point()
+ stat_smooth(method='lm')
+ facet_wrap('~children')
)
# Out:
# <ggplot: (159458595973)>

# %%
#age', 'bmi','children','charges  
(ggplot(excel_red, aes( 'children','charges', color='factor(age)'))
+ geom_point()
+ stat_smooth(method='lm')
+ facet_wrap('~age')
)
# Out:
# <ggplot: (159458865532)>

# %%
print("happy")
# Out:
# happy
